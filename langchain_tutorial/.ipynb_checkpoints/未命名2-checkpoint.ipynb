# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.schema import SystemMessage, HumanMessage


system = SystemMessage(content="'你是一个乐于助人的助手.'")
user = HumanMessage(content='根据下面的信息，回答问题：\n    \n    信息：\n    [Document(page_content=\'导论 7\\n者同盟”的邀请，将其改组为“共产主义 者同盟”，并为其起草了世界上 \\n第一个无产阶级政党的党纲——《共产党宣言》。1848年2月，《共产党 \\n宣言》发表，标志着马克思主义的公开问世。\\n《共产党宣言》发表的时候，正值1848年欧洲革命爆发。马克思、 \\n恩格斯领导共产主义 者同盟投身于这场规模巨大的资产阶级革命。为 \\n了阐明无产阶级在资产阶级革命中的策略，指导工人的斗争，马克思、 \\n恩格斯回 到德国科隆，创办了 《新莱茵报》。报纸停刊后，他们到革命 \\n地区活动，恩格斯还参与了起义并受到通缉。革命失败后，他们流亡 \\n英国，总结1848年革命的经验，丰富了无产阶级革命的理论。后来, \\n马克思留在伦敦开展理论研究 ，指导革命运动；恩格斯去了曼彻斯特, \\n进入父亲合股的企业，从经济上对马克思提供有力的支持，同时从事理 \\n论研究和革命活动。马克思进行了全面深入的政治经济学研究，撰写了 \\n《资本论》并出版了第一卷，系统阐述 了剩余价值 学说，揭示了资本主 \\n义生产关系的秘密。唯物史观和剩余价值 学说是马克思一生的两个伟大 \\n发现。\\n19世纪60年代，当沉寂多年 的欧洲工人运动再次兴起的时候，国 \\n际工人协会 （第一国际）于1864年9月在英国成立。马克思是协会的 \\n灵魂，为协会起草了大量重要文件。1871年3月，巴黎工人起义并成 \\n立巴黎公社，马克思代表第一国际写出了著名的《法兰西内战》，高度 \\n赞扬了巴黎工人的伟大创举，科学总结了巴黎公社的历史经验。该书以 \\n及几年后他写的《哥达纲领批判》，进一步丰富了科学社会主义学说。 \\n1876—1878年，恩格斯写出了 《反杜林论》，全面阐述了马克思主义理 \\n论体系。\\n长期繁重的工作损害了马克思的健康，但他即使 在多病的晚年，也 \\n没有停止奋斗。他一边为各国工人运动担当顾问，一边继续写作《资本 \\n论》，同时还向新的知识领 域进军，阅读了大量人类学和历史学著作并 \\n作了数量庞大的笔记。1883年3月14日马克思逝世后，恩格斯承担 起\', metadata={\'source\': \'./马克思主义基本原理（2023年版）.pdf\', \'page\': 15}), Document(page_content=\'8 导论\\n指导国际工人运动的重任，并整理出版了《资本论》第二、三卷，写出 \\n了《家庭、私有制和国家的起源》《路德维希-费尔巴哈和德国古典哲 \\n学的终结》等著作，进一步发展了马克思主义理论。1895年8月5日， \\n恩格斯与世长辞 。\\n马克思、恩格斯的著作\\n1953年1月，党中央决定成立中共中央马克思、恩格斯、列宁、斯大林 \\n著作编译局，以便有系统有计划地编译出版马克思、恩格斯、列宁、 \\n斯大林的全部著作。《马克思恩格斯 全集》中文第一版包括2 000多篇著作、 \\n4 000多封书信以及 400多篇其他相关文献，1956年开始出版，1985年出齐
学的立场观点方法是 能否正 \\n确预见未来的基本前提，也是马克思主义与空想社会主义的根本区别 。 \\n马克思主义经典作家站在科学的立场上，提出并自觉运用 了预见未来社会 \\n的方法论原则。这是我们展望未来 理想社会的基本依据，同时我们也应结 \\n合社会主义国家特别是中国发展的历史经验，自觉地运用和发展这些科学 \\n的方法论原则 。\\n（一）在揭示人类社会发展一般规律的基础上指明社会发展的方向\\n在人类历史上，有许许多多思想家热 切地关注着人类社会的未来，并 \\n提出自己的预见，特别是一些空想社会主义者曾详尽地描绘理想社会的图\', metadata={\'source\': \'./马克思主义基本原理（2023年版）.pdf\', \'page\': 332})]\n    \n    问题: \n    《共产党宣言》是什么时候发表的\n')

# %%
from langchain_wenxin import Wenxin

Wenxin("你好")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_wenxin import Wenxin
# ----> 3 Wenxin("你好")
#
# TypeError: Serializable.__init__() takes 1 positional argument but 2 were given

# %%
user = HumanMessage(content="请问一加一等于几")

# %%
from langchain_core.prompts import ChatPromptTemplate

prmpt = [
    system,
    user
    ]

# %%
from langchain_openai import ChatOpenAI, OpenAI

import os

os.environ["OPENAI_API_KEY"] = "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"
Chat = OpenAI()
Chat.invoke(prmpt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 7
#       5 os.environ["OPENAI_API_KEY"] = "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"
#       6 Chat = OpenAI()
# ----> 7 Chat.invoke(prmpt)
#
# File /Users/apple/anaconda3/envs/pytorch/lib/python3.11/site-packages/langchain_core/language_models/llms.py:273, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     263 def invoke(
#     264     self,
#     265     input: LanguageModelInput,
#    (...)
#     269     **kwargs: Any,
#     270 ) -> str:
#     271     config = ensure_config(config)
#     272     return (
# --> 273         self.generate_prompt(
#     274             [self._convert_input(input)],
#     275             stop=stop,
#     276             callbacks=config.get("callbacks"),
#     277             tags=config.get("tags"),
#     278             metadata=config.get("metadata"),
# ...

# %%
llm = OpenAI()
llm.invoke(
    "What are some theories about the relationship between unemployment and inflation?"
)

# %%
from langchain_wenxin.embeddings import WenxinEmbeddings

wenxin_embed = WenxinEmbeddings()



# print(wenxin_embed.embed_documents(["hello"]))

# %%
wenxin_embed.embed_documents('2')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 wenxin_embed.embed_documents('2')
#
# File /Users/apple/anaconda3/envs/pytorch/lib/python3.11/site-packages/langchain_wenxin/embeddings.py:81, in WenxinEmbeddings.embed_documents(self, texts)
#      79 all_embeddings = []
#      80 for batch in chunks(texts, batch_size):
# ---> 81     output = self.client.embed(
#      82         model=self.model, texts=batch, truncate=self.truncate
#      83     )
#      84     embeddings = output["data"]
#      85     embeddings = sorted(embeddings, key=lambda e: e["index"])
#
# File /Users/apple/anaconda3/envs/pytorch/lib/python3.11/site-packages/langchain_wenxin/client.py:336, in WenxinClient.embed(self, model, texts, truncate)
#     334     error_msg = response.get("error_msg", "Unknown error")
# ...
